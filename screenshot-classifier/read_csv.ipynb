# %%
import pandas as pd
import numpy as np

# %%
pdf = pd.read_csv('extracted_settings_flat.csv')

# %%
pdf.shape
# Out:
# (107, 5)

# %%
pdf.head(20)
# Out:
#     platform                                setting  \
# 0   Facebook                           Contact info
# 1   Facebook                               Birthday
# 2   Facebook                  Identity confirmation
# 3   Facebook          Account ownership and control
# 4   Facebook                        Change password
# 5   Facebook              Two-factor authentication
# 6   Facebook                            Saved login
# 7   Facebook                                Passkey
# 8   Facebook                 Where you're logged in
# 9   Facebook                           Login alerts
# 10  Facebook                          Recent emails
# 11  Facebook                       Security Checkup
# 12  Facebook         Who can see your future posts?
# 13  Facebook              Who can see your stories?
# 14  Facebook                 Reels default audience
# 15  Facebook       Limit past posts to only Friends
# 16  Facebook                    Add to blocked list
# ...
