# %%
import pandas as pd
import numpy as np

# %%
pdf = pd.read_csv('extracted_settings_flat.csv')

# %%
pdf.shape
# Out:
# (467, 5)

# %%
pdf.head(20)
# Out:
#    platform                         setting  \
# 0   chatgbt  Improve the model for everyone
# 1   chatgbt                    Shared links
# 2   chatgbt                  Archived chats
# 3   chatgbt               Archive all chats
# 4   chatgbt                Delete all chats
# 5   chatgbt                     Export data
# 6   chatgbt                        Nickname
# 7   chatgbt                      Occupation
# 8   chatgbt                  More about you
# 9   chatgbt        Reference saved memories
# 10  chatgbt          Reference chat history
# 11  chatgbt                      Web search
# 12  chatgbt                            Code
# 13  chatgbt                          Canvas
# 14  chatgbt                   ChatGPT Voice
# 15  chatgbt                   Separate mode
# 16  chatgbt                  Advanced voice
# 17  chatgbt                Connector search
# 18  chatgbt               Authenticator App
# 19  chatgbt          Log out of this device
#
# ...
