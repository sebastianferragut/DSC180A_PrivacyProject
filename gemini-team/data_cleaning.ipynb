# %%
import pandas as pd
import numpy as np
import json
from pprint import pprint

# %%
with open('picasso/click_counts/x.com_crawl_results.json') as fd:
     json_data = json.load(fd)
     pprint(json_data)
# Out:
# {'layer_dict': {'Layer 0': ['https://x.com/settings/account',
#                             'https://x.com/settings/security_and_account_access',
#                             'https://x.com/settings/privacy_and_safety',
#                             'https://x.com/settings/notifications',
#                             'https://x.com/settings/accessibility_display_and_languages'],
#                 'Layer 1': ['https://x.com/settings/your_twitter_data/account',
#                             'https://x.com/settings/password',
#                             'https://x.com/settings/download_your_data',
#                             'https://x.com/settings/deactivate',
#                             'https://x.com/settings/security',
#                             'https://x.com/settings/apps_and_sessions',
#                             'https://x.com/settings/connected_accounts',
#                             'https://x.com/settings/delegate',
# ...

# %%
len(json_data['layer_dict']['Layer 5'])
# Out:
# 1
