# %%
import pandas as pd
import numpy as np
import json
from pprint import pprint
import re

# %%
with open('picasso/click_counts/www.spotify.com_crawl_results.json') as fd:
     json_data = json.load(fd)
     pprint(json_data)
# Out:
# {'layer_dict': {'Layer 0': ['https://www.spotify.com/us/account/overview/'],
#                 'Layer 1': ['https://www.spotify.com/us/account/subscription/manage',
#                             'https://www.spotify.com/us/account/profile/',
#                             'https://www.spotify.com/us/account/recover-playlists/',
#                             'https://www.spotify.com/us/account/address/',
#                             'https://www.spotify.com/us/account/order-history/',
#                             'https://www.spotify.com/us/account/saved-payment-cards/',
#                             'https://www.spotify.com/us/account/redeem/',
#                             'https://www.spotify.com/us/account/apps/',
#                             'https://www.spotify.com/us/account/notifications/',
#                             'https://www.spotify.com/us/account/privacy/',
#                             'https://www.spotify.com/us/account/ad-preferences/',
# ...

# %%
len(json_data['layer_dict']['Layer 0'])
# Out:
# 1

# %%
# text = 'https://www.spotify.com/us/account/sign-out-everywhere/'
# safe = re.sub(r'[<>:"/\\|?*\x00-\x1f]', '_', str(text))
# safe

# %% [markdown]
# Click Count Analysis

# %%
pdf = pd.read_csv('picasso/url_to_click_count_map.csv')
pdf.head()
# Out:
#    platform                                                url  click_count
# 0  Facebook      https://accountscenter.facebook.com/profiles/            0
# 1  Facebook  https://accountscenter.facebook.com/password_a...            0
# 2  Facebook  https://accountscenter.facebook.com/info_and_p...            0
# 3  Facebook           https://accountscenter.facebook.com/ads/            0
# 4  Facebook        https://accountscenter.facebook.com/manage/            0

# %%
# mean
pdf.groupby('platform')['click_count'].mean()
# Out:
# platform
# Facebook    1.967742
# Linkedin    1.387283
# Reddit      0.833333
# X           1.671642
# Name: click_count, dtype: float64

# %%
# var
pdf.groupby('platform')['click_count'].var()
# Out:
# platform
# Facebook    1.632258
# Linkedin    0.308442
# Reddit      0.166667
# X           0.981456
# Name: click_count, dtype: float64

# %%
pdf.groupby('platform')['click_count'].describe()
# Out:
#           count      mean       std  min  25%  50%  75%  max
# platform
# Facebook   31.0  1.967742  1.277599  0.0  1.0  2.0  3.0  6.0
# Linkedin  173.0  1.387283  0.555376  0.0  1.0  1.0  2.0  2.0
# Reddit      6.0  0.833333  0.408248  0.0  1.0  1.0  1.0  1.0
# X          67.0  1.671642  0.990685  0.0  1.0  2.0  2.0  5.0
